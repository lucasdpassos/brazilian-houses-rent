# %% [markdown]
# <h2 style="color:purple"> Treino de Machine Learning - Casas para aluguel no Brasil </h2>

# %% [markdown]
# ![image info](./imgs/marker.png)

# %%
#Importando as bibliotecas

import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# ![image info](./imgs/marker.png)

# %%
#Lendo dados e criando dataFrame

df = pd.read_csv('./houses_to_rent.csv')
x = df.iloc[:, :-1].values
y = df.iloc[:, :5].values

df
# Out:
#       Unnamed: 0  city  area  rooms  bathroom  parking spaces floor  \
# 0              0     1   240      3         3               4     -
# 1              1     0    64      2         1               1    10
# 2              2     1   443      5         5               4     3
# 3              3     1    73      2         2               1    12
# 4              4     1    19      1         1               0     -
# ...          ...   ...   ...    ...       ...             ...   ...
# 6075        6075     1    50      2         1               1     2
# 6076        6076     1    84      2         2               1    16
# 6077        6077     0    48      1         1               0    13
# 6078        6078     1   160      3         2               2     -
# 6079        6079     1    60      2         1               1     4
#
#          animal      furniture      hoa rentamount propertytax fireinsurance  \
# ...

# %%
#Visualização dos dados
#Para criar a matriz de correlação

sns.heatmap(df.corr())

# %% [markdown]
# ![image info](./imgs/marker.png)

# %%
#Separando dados financeiros


data = df[['rentamount', 'propertytax', 'fireinsurance']]

data
# Out:
#      rentamount propertytax fireinsurance
# 0       R$8,000     R$1,000         R$121
# 1         R$820       R$122          R$11
# 2       R$7,000     R$1,417          R$89
# 3       R$1,250       R$150          R$16
# 4       R$1,200        R$41          R$16
# ...         ...         ...           ...
# 6075    R$1,150         R$0          R$15
# 6076    R$2,900        R$63          R$37
# 6077      R$950        R$42          R$13
# 6078    R$3,500       R$250          R$53
# 6079    R$1,900         R$0          R$25
#
# [6080 rows x 3 columns]
